# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
tierList = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND', 'MASTER', 'GRANDMASTER', 'CHALLENGER']
modelList = ['RandomForest', 'LightGBM', 'CatBoost', 'ExtraTree']
min5dataList = {}
for tier in tierList:
    df = pd.read_csv(f'../Dataset/perMinuteDataset/result/accuracy/{tier}.csv')
    CatBoost = df[df['Model'] == 'RandomForest']
    min5data = (CatBoost[CatBoost['Minute'] == 10])
    # min5dataList[tier] = min5data['accuracy_score'])
    print(min5data['accuracy_score'])
# Out:
# 20    74.24
# Name: accuracy_score, dtype: float64
# 20    71.67
# Name: accuracy_score, dtype: float64
# 20    75.58
# Name: accuracy_score, dtype: float64
# 20    71.39
# Name: accuracy_score, dtype: float64
# 20    70.55
# Name: accuracy_score, dtype: float64
# 20    71.04
# Name: accuracy_score, dtype: float64
# 20    72.13
# Name: accuracy_score, dtype: float64
# 20    71.84
# Name: accuracy_score, dtype: float64
# 20    73.23
# Name: accuracy_score, dtype: float64

# %%
tierList = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND', 'MASTER', 'GRANDMASTER', 'CHALLENGER']
modelList = ['RandomForest', 'LightGBM', 'CatBoost', 'ExtraTree']
plt.rcParams['font.family'] ='Malgun Gothic'
for tier in tierList:
    plt.figure(figsize=(20, 8))
    df = pd.read_csv(f'../Dataset/perMinuteDataset/result/accuracy/{tier}.csv')
    RandomForest = df[df['Model'] == 'RandomForest']
    LightGBM = df[df['Model'] == 'LightGBM']
    CatBoost = df[df['Model'] == 'CatBoost']
    ExtraTree = df[df['Model'] == 'ExtraTree']
    # plt.subplot(221)
    # plt.plot(RandomForest['Minute'], RandomForest['accuracy_score'], marker='o', linestyle='-')
    # plt.title(f'{tier} RandomForest Accuracy')
    # plt.xlabel('분')
    # plt.ylabel('정확도')
    # plt.grid(True)

    # plt.subplot(222)
    # plt.plot(LightGBM['Minute'], LightGBM['accuracy_score'], marker='o', linestyle='-')
    # plt.title(f'{tier} LightGBM Accuracy')
    # plt.xlabel('분')
    # plt.ylabel('정확도')
    # plt.grid(True)

    plt.subplot(223)
    plt.plot(CatBoost['Minute'], CatBoost['accuracy_score'], marker='o', linestyle='-')
    plt.title(f'{tier} CatBoost Accuracy')
    plt.xlabel('분')
    plt.ylabel('정확도')
    plt.grid(True)

    # plt.subplot(224)
    # plt.plot(ExtraTree['Minute'], ExtraTree['accuracy_score'], marker='o', linestyle='-')
    # plt.title(f'{tier} ExtraTree Accuracy')
    # plt.xlabel('분')
    # plt.ylabel('정확도')
    # plt.grid(True)

    plt.show()
